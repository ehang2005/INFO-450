# %% [markdown]
# <a href="https://colab.research.google.com/github/ehang2005/INFO-450/blob/main/Lesson6/INFO_450_Lesson_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
name = ""
print(name)
print(bool(name))
# Out:
# False

# %%
bool(-3)
# Out:
# True

# %% [markdown]
# #If statement

# %%
x=10
if x>5:
  print("x is greater than 5")
# Out:
# x is greater than 5

# %% [markdown]
# #If else statement

# %%
x=3
if x>5:
  print("x is greater than 5")
else:
  print("x is not greater than 5")
# Out:
# x is not greater than 5

# %%
x=81
if x>90:
  print("A")
elif x>80:
  print("B")
elif x>70:
  print("C")
else:
  print("summer school")
# Out:
# B

# %% [markdown]
# # Logical Operators

# %%
age=25
income=50000
# want to make sure they are going to pay me back
if (age>18 and income>40000) or income>400000:
  print("congrats on the loan")
# Out:
# congrats on the loan

# %%
hours_worked=40
performance_score=85
tenure=2 #years with company
if (hours_worked>40 and performance_score >80) or tenure>=2:
  print("promoted")
else:
  print("not")
# Out:
# promoted

# %%
x=3
y=4
if x==y:
  print("x and y are the same")
elif x<y:
  print("x is smaller")
else:
  print("y is smaller")
print("outside of if statment")
# Out:
# x is smaller
# outside of if statment

# %%
scores=[80,45,78,96,88]

# %%
if min(scores)>60:
  print("yall passed")
