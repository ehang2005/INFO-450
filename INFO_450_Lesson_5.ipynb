# %% [markdown]
# <a href="https://colab.research.google.com/github/ehang2005/INFO-450/blob/main/INFO_450_Lesson_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests

# %%
url = "https://raw.githubusercontent.com/ehang2005/INFO-450/refs/heads/main/Lesson%205/soccer.json"
response=requests.get(url)
response.status_code
response.raise_for_status()
data=response.json()
data.keys()
data['matches']
# Out:
# [{'round': 'First Stage, Group A',
#   'date': '2026-06-11',
#   'time': '13:00 UTC-6',
#   'team1': 'Mexico',
#   'team2': 'South Africa',
#   'score': {'ft': [2, 0], 'ht': [1, 0]},
#   'goals1': [{'name': 'Julian QUINONES', 'minute': '9'},
#    {'name': 'Raul JIMENEZ', 'minute': '67'}],
#   'goals2': [],
#   'ground': 'Mexico City Stadium, Mexico City',
#   'attendance': 80824,
#   'lineup': [{'starter': [{'name': 'Raul RANGEL'},
#      {'name': 'Cesar MONTES', 'captain': True},
#      {'name': 'Johan VASQUEZ'},
#      {'name': 'Israel REYES'},
#      {'name': 'Jesus GALLARDO'},
#      {'name': 'Erik LIRA'},
#      {'name': 'Alvaro FIDALGO'},
#      {'name': 'Brian GUTIERREZ'},
#      {'name': 'Raul JIMENEZ'},
#      {'name': 'Julian QUINONES'},
#      {'name': 'Roberto ALVARADO'}],
#     'bench': [{'name': 'Edson ALVAREZ'},
#      {'name': 'Gilberto MORA'},
#      {'name': 'Luis CHAVEZ'},
#      {'name': 'Armando GONZALEZ'},
#      {'name': 'Alexis VEGA'}],
# ...
